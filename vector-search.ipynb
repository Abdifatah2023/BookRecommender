# %%
pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\owner\appdata\roaming\python\python313\site-packages (1.0.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain-community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-community in c:\users\owner\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.41)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.11.0)
# Requirement already satisfied: certifi in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)

# %%
# !pip install langchain-openai langchain-chroma
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in c:\users\owner\appdata\roaming\python\python313\site-packages (1.0.2)
# Requirement already satisfied: langchain-chroma in c:\users\owner\appdata\roaming\python\python313\site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-openai) (1.0.4)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-openai) (2.7.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.11.0)
# Requirement already satisfied: certifi in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\owner\appdata\roaming\python\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\owner\appdata\roaming\python\python313\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: chromadb<2.0.0,>=1.0.20 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-chroma) (1.3.4)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from langchain-chroma) (2.3.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai) (2.3.0)
# Requirement already satisfied: pyproject_hooks in c:\users\owner\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\owner\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.28.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.33.0)
# Requirement already satisfied: sympy in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\owner\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.1.2)
# Requirement already satisfied: filelock in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.20.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (8.3.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.3.0)

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

books = pd.read_csv('updated_books.csv')
books
# Out:
#              isbn13                                       authors  \
# 0     9780002005883                            Marilynne Robinson
# 1     9780002261982               Charles Osborne;Agatha Christie
# 2     9780006178736                                Sidney Sheldon
# 3     9780006280897                           Clive Staples Lewis
# 4     9780006280934                           Clive Staples Lewis
# ...             ...                                           ...
# 5013  9788125026600                                   Marc Sautet
# 5014  9788171565641                                 E. M. Forster
# 5015  9788173031014                                 Hermann Hesse
# 5016  9788179921623                                  Robin Sharma
# 5017  9788185300535  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5013                  Uncategorized
# 5014                English fiction
# 5015              Adventure stories
# 5016               Health & Fitness
# 5017                     Philosophy
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5013  http://books.google.com/books/content?id=fPIv8...
# 5014  http://books.google.com/books/content?id=qWU9P...
# 5015  http://books.google.com/books/content?id=rq6JP...
# 5016  http://books.google.com/books/content?id=c_7mf...
# 5017  http://books.google.com/books/content?id=Fv_JP...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5013  Not only does Nietzsche for Beginners delve in...          2004.0
# 5014  Forster's lively, informed originality and wit...          2004.0
# 5015  This book tells the tale of a man who goes on ...          2002.0
# 5016  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5017  This collection of the timeless teachings of o...          1999.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5013            3.26      192.0           21.0
# 5014            3.83      141.0           10.0
# 5015            3.70      175.0           24.0
# 5016            3.82      198.0         1568.0
# 5017            4.51      531.0          104.0
#
#                                        title_&_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5013                            Nietzsche For Beginners
# 5014                               Aspects of the Novel
# 5015                                Journey to the East
# 5016  The Monk Who Sold His Ferrari: A Fable About F...
# 5017     I Am that: Talks with Sri Nisargadatta Maharaj
#
#                                      tagged_description
# 0     9780002005883 A NOVEL THAT READERS and critics...
# 1     9780002261982 A new 'Christie for Christmas' -...
# 2     9780006178736 A memorable, mesmerizing heroine...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4     9780006280934 "In The Problem of Pain, C.S. Le...
# ...                                                 ...
# 5013  9788125026600 Not only does Nietzsche for Begi...
# 5014  9788171565641 Forster's lively, informed origi...
# 5015  9788173031014 This book tells the tale of a ma...
# 5016  9788179921623 Wisdom to Create a Life of Passi...
# 5017  9788185300535 This collection of the timeless ...
#
# [5018 rows x 11 columns]

# %%
books["tagged_description"  ].to_csv("tagged_description.txt",
                                   index = False,
                                   header = False,
                                   encoding="utf-8")

# %%
raw_documents = TextLoader("tagged_description.txt", encoding="utf-8").load()
text_splitter = CharacterTextSplitter(chunk_size=400, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1170, which is longer than the specified 400
# Created a chunk of size 1216, which is longer than the specified 400
# Created a chunk of size 483, which is longer than the specified 400
# Created a chunk of size 484, which is longer than the specified 400
# Created a chunk of size 962, which is longer than the specified 400
# Created a chunk of size 845, which is longer than the specified 400
# Created a chunk of size 881, which is longer than the specified 400
# Created a chunk of size 1090, which is longer than the specified 400
# Created a chunk of size 1191, which is longer than the specified 400
# Created a chunk of size 515, which is longer than the specified 400
# Created a chunk of size 754, which is longer than the specified 400
# Created a chunk of size 730, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 475, which is longer than the specified 400
# Created a chunk of size 1267, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 523, which is longer than the specified 400
# Created a chunk of size 789, which is longer than the specified 400
# Created a chunk of size 566, which is longer than the specified 400
# Created a chunk of size 525, which is longer than the specified 400
# Created a chunk of size 535, which is longer than the specified 400
# Created a chunk of size 559, which is longer than the specified 400
# Created a chunk of size 565, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 463, which is longer than the specified 400
# Created a chunk of size 597, which is longer than the specified 400
# Created a chunk of size 478, which is longer than the specified 400
# Created a chunk of size 461, which is longer than the specified 400
# Created a chunk of size 616, which is longer than the specified 400
# Created a chunk of size 421, which is longer than the specified 400
# Created a chunk of size 889, which is longer than the specified 400
# Created a chunk of size 695, which is longer than the specified 400
# Created a chunk of size 2010, which is longer than the specified 400
# Created a chunk of size 481, which is longer than the specified 400
# Created a chunk of size 522, which is longer than the specified 400
# Created a chunk of size 649, which is longer than the specified 400
# Created a chunk of size 778, which is longer than the specified 400
# Created a chunk of size 688, which is longer than the specified 400
# Created a chunk of size 550, which is longer than the specified 400
# Created a chunk of size 1225, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 1186, which is longer than the specified 400
# Created a chunk of size 1216, which is longer than the specified 400
# Created a chunk of size 1193, which is longer than the specified 400
# Created a chunk of size 1059, which is longer than the specified 400
# Created a chunk of size 690, which is longer than the specified 400
# Created a chunk of size 878, which is longer than the specified 400
# Created a chunk of size 768, which is longer than the specified 400
# Created a chunk of size 419, which is longer than the specified 400
# Created a chunk of size 725, which is longer than the specified 400
# Created a chunk of size 528, which is longer than the specified 400
# Created a chunk of size 523, which is longer than the specified 400
# Created a chunk of size 901, which is longer than the specified 400
# Created a chunk of size 1272, which is longer than the specified 400
# Created a chunk of size 560, which is longer than the specified 400
# Created a chunk of size 1637, which is longer than the specified 400
# Created a chunk of size 438, which is longer than the specified 400
# Created a chunk of size 779, which is longer than the specified 400
# Created a chunk of size 718, which is longer than the specified 400
# Created a chunk of size 516, which is longer than the specified 400
# Created a chunk of size 960, which is longer than the specified 400
# Created a chunk of size 1132, which is longer than the specified 400
# Created a chunk of size 1325, which is longer than the specified 400
# Created a chunk of size 853, which is longer than the specified 400
# Created a chunk of size 801, which is longer than the specified 400
# Created a chunk of size 1121, which is longer than the specified 400
# Created a chunk of size 838, which is longer than the specified 400
# Created a chunk of size 734, which is longer than the specified 400
# Created a chunk of size 1195, which is longer than the specified 400
# Created a chunk of size 712, which is longer than the specified 400
# Created a chunk of size 775, which is longer than the specified 400
# Created a chunk of size 768, which is longer than the specified 400
# Created a chunk of size 767, which is longer than the specified 400
# Created a chunk of size 718, which is longer than the specified 400
# Created a chunk of size 2012, which is longer than the specified 400
# Created a chunk of size 1288, which is longer than the specified 400
# Created a chunk of size 1231, which is longer than the specified 400
# Created a chunk of size 729, which is longer than the specified 400
# Created a chunk of size 750, which is longer than the specified 400
# Created a chunk of size 447, which is longer than the specified 400
# Created a chunk of size 1242, which is longer than the specified 400
# Created a chunk of size 914, which is longer than the specified 400
# Created a chunk of size 846, which is longer than the specified 400
# Created a chunk of size 1128, which is longer than the specified 400
# Created a chunk of size 1075, which is longer than the specified 400
# Created a chunk of size 1320, which is longer than the specified 400
# Created a chunk of size 2834, which is longer than the specified 400
# Created a chunk of size 572, which is longer than the specified 400
# Created a chunk of size 1143, which is longer than the specified 400
# Created a chunk of size 1006, which is longer than the specified 400
# Created a chunk of size 715, which is longer than the specified 400
# Created a chunk of size 712, which is longer than the specified 400
# Created a chunk of size 2510, which is longer than the specified 400
# Created a chunk of size 956, which is longer than the specified 400
# Created a chunk of size 641, which is longer than the specified 400
# Created a chunk of size 405, which is longer than the specified 400
# Created a chunk of size 525, which is longer than the specified 400
# Created a chunk of size 795, which is longer than the specified 400
# Created a chunk of size 1424, which is longer than the specified 400
# Created a chunk of size 1085, which is longer than the specified 400
# Created a chunk of size 1146, which is longer than the specified 400
# Created a chunk of size 1268, which is longer than the specified 400
# Created a chunk of size 790, which is longer than the specified 400
# Created a chunk of size 1088, which is longer than the specified 400
# Created a chunk of size 874, which is longer than the specified 400
# Created a chunk of size 876, which is longer than the specified 400
# Created a chunk of size 808, which is longer than the specified 400
# Created a chunk of size 1814, which is longer than the specified 400
# Created a chunk of size 1830, which is longer than the specified 400
# Created a chunk of size 1064, which is longer than the specified 400
# Created a chunk of size 955, which is longer than the specified 400
# Created a chunk of size 1182, which is longer than the specified 400
# Created a chunk of size 1286, which is longer than the specified 400
# Created a chunk of size 1644, which is longer than the specified 400
# Created a chunk of size 759, which is longer than the specified 400
# Created a chunk of size 1932, which is longer than the specified 400
# Created a chunk of size 874, which is longer than the specified 400
# Created a chunk of size 2008, which is longer than the specified 400
# Created a chunk of size 2285, which is longer than the specified 400
# Created a chunk of size 1003, which is longer than the specified 400
# Created a chunk of size 579, which is longer than the specified 400
# Created a chunk of size 1144, which is longer than the specified 400
# Created a chunk of size 559, which is longer than the specified 400
# Created a chunk of size 1143, which is longer than the specified 400
# Created a chunk of size 1088, which is longer than the specified 400
# Created a chunk of size 1483, which is longer than the specified 400
# Created a chunk of size 1137, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 668, which is longer than the specified 400
# Created a chunk of size 767, which is longer than the specified 400
# Created a chunk of size 608, which is longer than the specified 400
# Created a chunk of size 572, which is longer than the specified 400
# Created a chunk of size 967, which is longer than the specified 400
# Created a chunk of size 859, which is longer than the specified 400
# Created a chunk of size 1034, which is longer than the specified 400
# Created a chunk of size 497, which is longer than the specified 400
# Created a chunk of size 652, which is longer than the specified 400
# Created a chunk of size 735, which is longer than the specified 400
# Created a chunk of size 527, which is longer than the specified 400
# Created a chunk of size 1017, which is longer than the specified 400
# Created a chunk of size 972, which is longer than the specified 400
# Created a chunk of size 690, which is longer than the specified 400
# Created a chunk of size 546, which is longer than the specified 400
# Created a chunk of size 933, which is longer than the specified 400
# Created a chunk of size 564, which is longer than the specified 400
# Created a chunk of size 856, which is longer than the specified 400
# Created a chunk of size 717, which is longer than the specified 400
# Created a chunk of size 749, which is longer than the specified 400
# Created a chunk of size 714, which is longer than the specified 400
# Created a chunk of size 1090, which is longer than the specified 400
# Created a chunk of size 725, which is longer than the specified 400
# Created a chunk of size 706, which is longer than the specified 400
# Created a chunk of size 1914, which is longer than the specified 400
# Created a chunk of size 487, which is longer than the specified 400
# Created a chunk of size 622, which is longer than the specified 400
# Created a chunk of size 561, which is longer than the specified 400
# Created a chunk of size 558, which is longer than the specified 400
# Created a chunk of size 427, which is longer than the specified 400
# Created a chunk of size 418, which is longer than the specified 400
# Created a chunk of size 626, which is longer than the specified 400
# Created a chunk of size 2616, which is longer than the specified 400
# Created a chunk of size 1580, which is longer than the specified 400
# Created a chunk of size 996, which is longer than the specified 400
# Created a chunk of size 849, which is longer than the specified 400
# Created a chunk of size 1530, which is longer than the specified 400
# Created a chunk of size 2032, which is longer than the specified 400
# Created a chunk of size 1619, which is longer than the specified 400
# Created a chunk of size 700, which is longer than the specified 400
# Created a chunk of size 824, which is longer than the specified 400
# Created a chunk of size 843, which is longer than the specified 400
# Created a chunk of size 1191, which is longer than the specified 400
# Created a chunk of size 510, which is longer than the specified 400
# Created a chunk of size 665, which is longer than the specified 400
# Created a chunk of size 1284, which is longer than the specified 400
# Created a chunk of size 1268, which is longer than the specified 400
# Created a chunk of size 1277, which is longer than the specified 400
# Created a chunk of size 1058, which is longer than the specified 400
# Created a chunk of size 784, which is longer than the specified 400
# Created a chunk of size 971, which is longer than the specified 400
# Created a chunk of size 615, which is longer than the specified 400
# Created a chunk of size 759, which is longer than the specified 400
# Created a chunk of size 965, which is longer than the specified 400
# Created a chunk of size 845, which is longer than the specified 400
# Created a chunk of size 788, which is longer than the specified 400
# Created a chunk of size 650, which is longer than the specified 400
# Created a chunk of size 986, which is longer than the specified 400
# Created a chunk of size 799, which is longer than the specified 400
# Created a chunk of size 1163, which is longer than the specified 400
# Created a chunk of size 1058, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 819, which is longer than the specified 400
# Created a chunk of size 757, which is longer than the specified 400
# Created a chunk of size 571, which is longer than the specified 400
# Created a chunk of size 628, which is longer than the specified 400
# Created a chunk of size 868, which is longer than the specified 400
# Created a chunk of size 622, which is longer than the specified 400
# Created a chunk of size 623, which is longer than the specified 400
# Created a chunk of size 1084, which is longer than the specified 400
# Created a chunk of size 2762, which is longer than the specified 400
# Created a chunk of size 1035, which is longer than the specified 400
# Created a chunk of size 760, which is longer than the specified 400
# Created a chunk of size 775, which is longer than the specified 400
# Created a chunk of size 636, which is longer than the specified 400
# Created a chunk of size 1010, which is longer than the specified 400
# Created a chunk of size 1066, which is longer than the specified 400
# Created a chunk of size 494, which is longer than the specified 400
# Created a chunk of size 797, which is longer than the specified 400
# Created a chunk of size 701, which is longer than the specified 400
# Created a chunk of size 487, which is longer than the specified 400
# Created a chunk of size 1226, which is longer than the specified 400
# Created a chunk of size 659, which is longer than the specified 400
# Created a chunk of size 767, which is longer than the specified 400
# Created a chunk of size 555, which is longer than the specified 400
# Created a chunk of size 592, which is longer than the specified 400
# Created a chunk of size 728, which is longer than the specified 400
# Created a chunk of size 1807, which is longer than the specified 400
# Created a chunk of size 1017, which is longer than the specified 400
# Created a chunk of size 684, which is longer than the specified 400
# Created a chunk of size 741, which is longer than the specified 400
# Created a chunk of size 451, which is longer than the specified 400
# Created a chunk of size 474, which is longer than the specified 400
# Created a chunk of size 924, which is longer than the specified 400
# Created a chunk of size 969, which is longer than the specified 400
# Created a chunk of size 479, which is longer than the specified 400
# Created a chunk of size 647, which is longer than the specified 400
# Created a chunk of size 678, which is longer than the specified 400
# Created a chunk of size 712, which is longer than the specified 400
# Created a chunk of size 801, which is longer than the specified 400
# Created a chunk of size 856, which is longer than the specified 400
# Created a chunk of size 672, which is longer than the specified 400
# Created a chunk of size 854, which is longer than the specified 400
# Created a chunk of size 762, which is longer than the specified 400
# Created a chunk of size 798, which is longer than the specified 400
# Created a chunk of size 681, which is longer than the specified 400
# Created a chunk of size 929, which is longer than the specified 400
# Created a chunk of size 1268, which is longer than the specified 400
# Created a chunk of size 735, which is longer than the specified 400
# Created a chunk of size 870, which is longer than the specified 400
# Created a chunk of size 933, which is longer than the specified 400
# Created a chunk of size 774, which is longer than the specified 400
# Created a chunk of size 772, which is longer than the specified 400
# Created a chunk of size 649, which is longer than the specified 400
# Created a chunk of size 1771, which is longer than the specified 400
# Created a chunk of size 536, which is longer than the specified 400
# Created a chunk of size 826, which is longer than the specified 400
# Created a chunk of size 599, which is longer than the specified 400
# Created a chunk of size 488, which is longer than the specified 400
# Created a chunk of size 971, which is longer than the specified 400
# Created a chunk of size 556, which is longer than the specified 400
# Created a chunk of size 491, which is longer than the specified 400
# Created a chunk of size 844, which is longer than the specified 400
# Created a chunk of size 878, which is longer than the specified 400
# Created a chunk of size 672, which is longer than the specified 400
# Created a chunk of size 709, which is longer than the specified 400
# Created a chunk of size 656, which is longer than the specified 400
# Created a chunk of size 1270, which is longer than the specified 400
# Created a chunk of size 738, which is longer than the specified 400
# Created a chunk of size 1019, which is longer than the specified 400
# Created a chunk of size 779, which is longer than the specified 400
# Created a chunk of size 684, which is longer than the specified 400
# Created a chunk of size 600, which is longer than the specified 400
# Created a chunk of size 665, which is longer than the specified 400
# Created a chunk of size 597, which is longer than the specified 400
# Created a chunk of size 857, which is longer than the specified 400
# Created a chunk of size 597, which is longer than the specified 400
# Created a chunk of size 539, which is longer than the specified 400
# Created a chunk of size 567, which is longer than the specified 400
# Created a chunk of size 707, which is longer than the specified 400
# Created a chunk of size 850, which is longer than the specified 400
# Created a chunk of size 544, which is longer than the specified 400
# Created a chunk of size 1179, which is longer than the specified 400
# Created a chunk of size 460, which is longer than the specified 400
# Created a chunk of size 906, which is longer than the specified 400
# Created a chunk of size 854, which is longer than the specified 400
# Created a chunk of size 509, which is longer than the specified 400
# Created a chunk of size 1717, which is longer than the specified 400
# Created a chunk of size 847, which is longer than the specified 400
# Created a chunk of size 1681, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 661, which is longer than the specified 400
# Created a chunk of size 605, which is longer than the specified 400
# Created a chunk of size 993, which is longer than the specified 400
# Created a chunk of size 1130, which is longer than the specified 400
# Created a chunk of size 464, which is longer than the specified 400
# Created a chunk of size 2005, which is longer than the specified 400
# Created a chunk of size 1173, which is longer than the specified 400
# Created a chunk of size 2141, which is longer than the specified 400
# Created a chunk of size 664, which is longer than the specified 400
# Created a chunk of size 1322, which is longer than the specified 400
# Created a chunk of size 1114, which is longer than the specified 400
# Created a chunk of size 666, which is longer than the specified 400
# Created a chunk of size 1318, which is longer than the specified 400
# Created a chunk of size 693, which is longer than the specified 400
# Created a chunk of size 952, which is longer than the specified 400
# Created a chunk of size 1123, which is longer than the specified 400
# Created a chunk of size 776, which is longer than the specified 400
# Created a chunk of size 615, which is longer than the specified 400
# Created a chunk of size 425, which is longer than the specified 400
# Created a chunk of size 533, which is longer than the specified 400
# Created a chunk of size 1020, which is longer than the specified 400
# Created a chunk of size 727, which is longer than the specified 400
# Created a chunk of size 612, which is longer than the specified 400
# Created a chunk of size 631, which is longer than the specified 400
# Created a chunk of size 465, which is longer than the specified 400
# Created a chunk of size 1009, which is longer than the specified 400
# Created a chunk of size 618, which is longer than the specified 400
# Created a chunk of size 884, which is longer than the specified 400
# Created a chunk of size 581, which is longer than the specified 400
# Created a chunk of size 911, which is longer than the specified 400
# Created a chunk of size 1059, which is longer than the specified 400
# Created a chunk of size 632, which is longer than the specified 400
# Created a chunk of size 1255, which is longer than the specified 400
# Created a chunk of size 572, which is longer than the specified 400
# Created a chunk of size 1100, which is longer than the specified 400
# Created a chunk of size 909, which is longer than the specified 400
# Created a chunk of size 623, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 450, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 1145, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 622, which is longer than the specified 400
# Created a chunk of size 627, which is longer than the specified 400
# Created a chunk of size 553, which is longer than the specified 400
# Created a chunk of size 843, which is longer than the specified 400
# Created a chunk of size 483, which is longer than the specified 400
# Created a chunk of size 716, which is longer than the specified 400
# Created a chunk of size 923, which is longer than the specified 400
# Created a chunk of size 583, which is longer than the specified 400
# Created a chunk of size 746, which is longer than the specified 400
# Created a chunk of size 556, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 543, which is longer than the specified 400
# Created a chunk of size 752, which is longer than the specified 400
# Created a chunk of size 614, which is longer than the specified 400
# Created a chunk of size 497, which is longer than the specified 400
# Created a chunk of size 613, which is longer than the specified 400
# Created a chunk of size 589, which is longer than the specified 400
# Created a chunk of size 811, which is longer than the specified 400
# Created a chunk of size 601, which is longer than the specified 400
# Created a chunk of size 1552, which is longer than the specified 400
# Created a chunk of size 592, which is longer than the specified 400
# Created a chunk of size 829, which is longer than the specified 400
# Created a chunk of size 666, which is longer than the specified 400
# Created a chunk of size 879, which is longer than the specified 400
# Created a chunk of size 736, which is longer than the specified 400
# Created a chunk of size 431, which is longer than the specified 400
# Created a chunk of size 725, which is longer than the specified 400
# Created a chunk of size 509, which is longer than the specified 400
# Created a chunk of size 424, which is longer than the specified 400
# Created a chunk of size 925, which is longer than the specified 400
# Created a chunk of size 549, which is longer than the specified 400
# Created a chunk of size 1654, which is longer than the specified 400
# Created a chunk of size 875, which is longer than the specified 400
# Created a chunk of size 476, which is longer than the specified 400
# Created a chunk of size 738, which is longer than the specified 400
# Created a chunk of size 529, which is longer than the specified 400
# Created a chunk of size 614, which is longer than the specified 400
# Created a chunk of size 801, which is longer than the specified 400
# Created a chunk of size 438, which is longer than the specified 400
# Created a chunk of size 540, which is longer than the specified 400
# Created a chunk of size 547, which is longer than the specified 400
# Created a chunk of size 461, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 976, which is longer than the specified 400
# Created a chunk of size 926, which is longer than the specified 400
# Created a chunk of size 554, which is longer than the specified 400
# Created a chunk of size 674, which is longer than the specified 400
# Created a chunk of size 791, which is longer than the specified 400
# Created a chunk of size 638, which is longer than the specified 400
# Created a chunk of size 418, which is longer than the specified 400
# Created a chunk of size 615, which is longer than the specified 400
# Created a chunk of size 993, which is longer than the specified 400
# Created a chunk of size 450, which is longer than the specified 400
# Created a chunk of size 678, which is longer than the specified 400
# Created a chunk of size 452, which is longer than the specified 400
# Created a chunk of size 583, which is longer than the specified 400
# Created a chunk of size 585, which is longer than the specified 400
# Created a chunk of size 777, which is longer than the specified 400
# Created a chunk of size 532, which is longer than the specified 400
# Created a chunk of size 615, which is longer than the specified 400
# Created a chunk of size 834, which is longer than the specified 400
# Created a chunk of size 436, which is longer than the specified 400
# Created a chunk of size 824, which is longer than the specified 400
# Created a chunk of size 465, which is longer than the specified 400
# Created a chunk of size 888, which is longer than the specified 400
# Created a chunk of size 1279, which is longer than the specified 400
# Created a chunk of size 668, which is longer than the specified 400
# Created a chunk of size 849, which is longer than the specified 400
# Created a chunk of size 1048, which is longer than the specified 400
# Created a chunk of size 672, which is longer than the specified 400
# Created a chunk of size 465, which is longer than the specified 400
# Created a chunk of size 556, which is longer than the specified 400
# Created a chunk of size 916, which is longer than the specified 400
# Created a chunk of size 757, which is longer than the specified 400
# Created a chunk of size 759, which is longer than the specified 400
# Created a chunk of size 947, which is longer than the specified 400
# Created a chunk of size 907, which is longer than the specified 400
# Created a chunk of size 849, which is longer than the specified 400
# Created a chunk of size 867, which is longer than the specified 400
# Created a chunk of size 804, which is longer than the specified 400
# Created a chunk of size 839, which is longer than the specified 400
# Created a chunk of size 756, which is longer than the specified 400
# Created a chunk of size 866, which is longer than the specified 400
# Created a chunk of size 801, which is longer than the specified 400
# Created a chunk of size 680, which is longer than the specified 400
# Created a chunk of size 513, which is longer than the specified 400
# Created a chunk of size 544, which is longer than the specified 400
# Created a chunk of size 818, which is longer than the specified 400
# Created a chunk of size 745, which is longer than the specified 400
# Created a chunk of size 674, which is longer than the specified 400
# Created a chunk of size 672, which is longer than the specified 400
# Created a chunk of size 478, which is longer than the specified 400
# Created a chunk of size 992, which is longer than the specified 400
# Created a chunk of size 769, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 996, which is longer than the specified 400
# Created a chunk of size 574, which is longer than the specified 400
# Created a chunk of size 474, which is longer than the specified 400
# Created a chunk of size 639, which is longer than the specified 400
# Created a chunk of size 609, which is longer than the specified 400
# Created a chunk of size 1668, which is longer than the specified 400
# Created a chunk of size 1618, which is longer than the specified 400
# Created a chunk of size 780, which is longer than the specified 400
# Created a chunk of size 576, which is longer than the specified 400
# Created a chunk of size 671, which is longer than the specified 400
# Created a chunk of size 816, which is longer than the specified 400
# Created a chunk of size 444, which is longer than the specified 400
# Created a chunk of size 520, which is longer than the specified 400
# Created a chunk of size 489, which is longer than the specified 400
# Created a chunk of size 609, which is longer than the specified 400
# Created a chunk of size 735, which is longer than the specified 400
# Created a chunk of size 1097, which is longer than the specified 400
# Created a chunk of size 1599, which is longer than the specified 400
# Created a chunk of size 946, which is longer than the specified 400
# Created a chunk of size 1962, which is longer than the specified 400
# Created a chunk of size 597, which is longer than the specified 400
# Created a chunk of size 1710, which is longer than the specified 400
# Created a chunk of size 897, which is longer than the specified 400
# Created a chunk of size 636, which is longer than the specified 400
# Created a chunk of size 996, which is longer than the specified 400
# Created a chunk of size 1949, which is longer than the specified 400
# Created a chunk of size 1027, which is longer than the specified 400
# Created a chunk of size 618, which is longer than the specified 400
# Created a chunk of size 496, which is longer than the specified 400
# Created a chunk of size 468, which is longer than the specified 400
# Created a chunk of size 1809, which is longer than the specified 400
# Created a chunk of size 619, which is longer than the specified 400
# Created a chunk of size 644, which is longer than the specified 400
# Created a chunk of size 1520, which is longer than the specified 400
# Created a chunk of size 755, which is longer than the specified 400
# Created a chunk of size 616, which is longer than the specified 400
# Created a chunk of size 461, which is longer than the specified 400
# Created a chunk of size 690, which is longer than the specified 400
# Created a chunk of size 811, which is longer than the specified 400
# Created a chunk of size 538, which is longer than the specified 400
# Created a chunk of size 869, which is longer than the specified 400
# Created a chunk of size 485, which is longer than the specified 400
# Created a chunk of size 892, which is longer than the specified 400
# Created a chunk of size 561, which is longer than the specified 400
# Created a chunk of size 1089, which is longer than the specified 400
# Created a chunk of size 418, which is longer than the specified 400
# Created a chunk of size 732, which is longer than the specified 400
# Created a chunk of size 534, which is longer than the specified 400
# Created a chunk of size 615, which is longer than the specified 400
# Created a chunk of size 402, which is longer than the specified 400
# Created a chunk of size 1095, which is longer than the specified 400
# Created a chunk of size 437, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 880, which is longer than the specified 400
# Created a chunk of size 981, which is longer than the specified 400
# Created a chunk of size 988, which is longer than the specified 400
# Created a chunk of size 535, which is longer than the specified 400
# Created a chunk of size 1167, which is longer than the specified 400
# Created a chunk of size 1261, which is longer than the specified 400
# Created a chunk of size 1482, which is longer than the specified 400
# Created a chunk of size 818, which is longer than the specified 400
# Created a chunk of size 1039, which is longer than the specified 400
# Created a chunk of size 1087, which is longer than the specified 400
# Created a chunk of size 1445, which is longer than the specified 400
# Created a chunk of size 1268, which is longer than the specified 400
# Created a chunk of size 1146, which is longer than the specified 400
# Created a chunk of size 1371, which is longer than the specified 400
# Created a chunk of size 1624, which is longer than the specified 400
# Created a chunk of size 1167, which is longer than the specified 400
# Created a chunk of size 583, which is longer than the specified 400
# Created a chunk of size 785, which is longer than the specified 400
# Created a chunk of size 1178, which is longer than the specified 400
# Created a chunk of size 1181, which is longer than the specified 400
# Created a chunk of size 732, which is longer than the specified 400
# Created a chunk of size 828, which is longer than the specified 400
# Created a chunk of size 597, which is longer than the specified 400
# Created a chunk of size 1000, which is longer than the specified 400
# Created a chunk of size 462, which is longer than the specified 400
# Created a chunk of size 1011, which is longer than the specified 400
# Created a chunk of size 665, which is longer than the specified 400
# Created a chunk of size 1024, which is longer than the specified 400
# Created a chunk of size 747, which is longer than the specified 400
# Created a chunk of size 1359, which is longer than the specified 400
# Created a chunk of size 815, which is longer than the specified 400
# Created a chunk of size 426, which is longer than the specified 400
# Created a chunk of size 1174, which is longer than the specified 400
# Created a chunk of size 1396, which is longer than the specified 400
# Created a chunk of size 1218, which is longer than the specified 400
# Created a chunk of size 465, which is longer than the specified 400
# Created a chunk of size 423, which is longer than the specified 400
# Created a chunk of size 605, which is longer than the specified 400
# Created a chunk of size 2209, which is longer than the specified 400
# Created a chunk of size 1373, which is longer than the specified 400
# Created a chunk of size 2877, which is longer than the specified 400
# Created a chunk of size 793, which is longer than the specified 400
# Created a chunk of size 791, which is longer than the specified 400
# Created a chunk of size 779, which is longer than the specified 400
# Created a chunk of size 1714, which is longer than the specified 400
# Created a chunk of size 1640, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 513, which is longer than the specified 400
# Created a chunk of size 519, which is longer than the specified 400
# Created a chunk of size 2400, which is longer than the specified 400
# Created a chunk of size 825, which is longer than the specified 400
# Created a chunk of size 2122, which is longer than the specified 400
# Created a chunk of size 1490, which is longer than the specified 400
# Created a chunk of size 1693, which is longer than the specified 400
# Created a chunk of size 845, which is longer than the specified 400
# Created a chunk of size 1420, which is longer than the specified 400
# Created a chunk of size 793, which is longer than the specified 400
# Created a chunk of size 1173, which is longer than the specified 400
# Created a chunk of size 1359, which is longer than the specified 400
# Created a chunk of size 458, which is longer than the specified 400
# Created a chunk of size 826, which is longer than the specified 400
# Created a chunk of size 915, which is longer than the specified 400
# Created a chunk of size 436, which is longer than the specified 400
# Created a chunk of size 2181, which is longer than the specified 400
# Created a chunk of size 1095, which is longer than the specified 400
# Created a chunk of size 2171, which is longer than the specified 400
# Created a chunk of size 1456, which is longer than the specified 400
# Created a chunk of size 1456, which is longer than the specified 400
# Created a chunk of size 584, which is longer than the specified 400
# Created a chunk of size 1975, which is longer than the specified 400
# Created a chunk of size 1987, which is longer than the specified 400
# Created a chunk of size 1648, which is longer than the specified 400
# Created a chunk of size 1634, which is longer than the specified 400
# Created a chunk of size 476, which is longer than the specified 400
# Created a chunk of size 940, which is longer than the specified 400
# Created a chunk of size 503, which is longer than the specified 400
# Created a chunk of size 1286, which is longer than the specified 400
# Created a chunk of size 1484, which is longer than the specified 400
# Created a chunk of size 692, which is longer than the specified 400
# Created a chunk of size 469, which is longer than the specified 400
# Created a chunk of size 1005, which is longer than the specified 400
# Created a chunk of size 453, which is longer than the specified 400
# Created a chunk of size 1216, which is longer than the specified 400
# Created a chunk of size 899, which is longer than the specified 400
# Created a chunk of size 610, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 947, which is longer than the specified 400
# Created a chunk of size 1032, which is longer than the specified 400
# Created a chunk of size 2456, which is longer than the specified 400
# Created a chunk of size 1349, which is longer than the specified 400
# Created a chunk of size 1271, which is longer than the specified 400
# Created a chunk of size 1119, which is longer than the specified 400
# Created a chunk of size 1548, which is longer than the specified 400
# Created a chunk of size 1201, which is longer than the specified 400
# Created a chunk of size 554, which is longer than the specified 400
# Created a chunk of size 504, which is longer than the specified 400
# Created a chunk of size 757, which is longer than the specified 400
# Created a chunk of size 977, which is longer than the specified 400
# Created a chunk of size 543, which is longer than the specified 400
# Created a chunk of size 998, which is longer than the specified 400
# Created a chunk of size 1162, which is longer than the specified 400
# Created a chunk of size 622, which is longer than the specified 400
# Created a chunk of size 724, which is longer than the specified 400
# Created a chunk of size 1149, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 839, which is longer than the specified 400
# Created a chunk of size 964, which is longer than the specified 400
# Created a chunk of size 1024, which is longer than the specified 400
# Created a chunk of size 1776, which is longer than the specified 400
# Created a chunk of size 1165, which is longer than the specified 400
# Created a chunk of size 541, which is longer than the specified 400
# Created a chunk of size 1011, which is longer than the specified 400
# Created a chunk of size 579, which is longer than the specified 400
# Created a chunk of size 755, which is longer than the specified 400
# Created a chunk of size 429, which is longer than the specified 400
# Created a chunk of size 433, which is longer than the specified 400
# Created a chunk of size 1019, which is longer than the specified 400
# Created a chunk of size 1325, which is longer than the specified 400
# Created a chunk of size 911, which is longer than the specified 400
# Created a chunk of size 464, which is longer than the specified 400
# Created a chunk of size 663, which is longer than the specified 400
# Created a chunk of size 753, which is longer than the specified 400
# Created a chunk of size 558, which is longer than the specified 400
# Created a chunk of size 1125, which is longer than the specified 400
# Created a chunk of size 607, which is longer than the specified 400
# Created a chunk of size 459, which is longer than the specified 400
# Created a chunk of size 1598, which is longer than the specified 400
# Created a chunk of size 495, which is longer than the specified 400
# Created a chunk of size 1963, which is longer than the specified 400
# Created a chunk of size 896, which is longer than the specified 400
# Created a chunk of size 693, which is longer than the specified 400
# Created a chunk of size 509, which is longer than the specified 400
# Created a chunk of size 2450, which is longer than the specified 400
# Created a chunk of size 1798, which is longer than the specified 400
# Created a chunk of size 1568, which is longer than the specified 400
# Created a chunk of size 1221, which is longer than the specified 400
# Created a chunk of size 759, which is longer than the specified 400
# Created a chunk of size 880, which is longer than the specified 400
# Created a chunk of size 1382, which is longer than the specified 400
# Created a chunk of size 403, which is longer than the specified 400
# Created a chunk of size 854, which is longer than the specified 400
# Created a chunk of size 1452, which is longer than the specified 400
# Created a chunk of size 1104, which is longer than the specified 400
# Created a chunk of size 402, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 1300, which is longer than the specified 400
# Created a chunk of size 492, which is longer than the specified 400
# Created a chunk of size 778, which is longer than the specified 400
# Created a chunk of size 909, which is longer than the specified 400
# Created a chunk of size 995, which is longer than the specified 400
# Created a chunk of size 775, which is longer than the specified 400
# Created a chunk of size 1763, which is longer than the specified 400
# Created a chunk of size 1006, which is longer than the specified 400
# Created a chunk of size 1024, which is longer than the specified 400
# Created a chunk of size 770, which is longer than the specified 400
# Created a chunk of size 658, which is longer than the specified 400
# Created a chunk of size 467, which is longer than the specified 400
# Created a chunk of size 586, which is longer than the specified 400
# Created a chunk of size 642, which is longer than the specified 400
# Created a chunk of size 733, which is longer than the specified 400
# Created a chunk of size 636, which is longer than the specified 400
# Created a chunk of size 923, which is longer than the specified 400
# Created a chunk of size 1066, which is longer than the specified 400
# Created a chunk of size 868, which is longer than the specified 400
# Created a chunk of size 1011, which is longer than the specified 400
# Created a chunk of size 767, which is longer than the specified 400
# Created a chunk of size 988, which is longer than the specified 400
# Created a chunk of size 788, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 1064, which is longer than the specified 400
# Created a chunk of size 1629, which is longer than the specified 400
# Created a chunk of size 1593, which is longer than the specified 400
# Created a chunk of size 625, which is longer than the specified 400
# Created a chunk of size 827, which is longer than the specified 400
# Created a chunk of size 1587, which is longer than the specified 400
# Created a chunk of size 407, which is longer than the specified 400
# Created a chunk of size 573, which is longer than the specified 400
# Created a chunk of size 1261, which is longer than the specified 400
# Created a chunk of size 1130, which is longer than the specified 400
# Created a chunk of size 1105, which is longer than the specified 400
# Created a chunk of size 483, which is longer than the specified 400
# Created a chunk of size 848, which is longer than the specified 400
# Created a chunk of size 792, which is longer than the specified 400
# Created a chunk of size 784, which is longer than the specified 400
# Created a chunk of size 659, which is longer than the specified 400
# Created a chunk of size 951, which is longer than the specified 400
# Created a chunk of size 478, which is longer than the specified 400
# Created a chunk of size 847, which is longer than the specified 400
# Created a chunk of size 760, which is longer than the specified 400
# Created a chunk of size 1080, which is longer than the specified 400
# Created a chunk of size 1533, which is longer than the specified 400
# Created a chunk of size 792, which is longer than the specified 400
# Created a chunk of size 825, which is longer than the specified 400
# Created a chunk of size 1204, which is longer than the specified 400
# Created a chunk of size 1095, which is longer than the specified 400
# Created a chunk of size 1249, which is longer than the specified 400
# Created a chunk of size 1056, which is longer than the specified 400
# Created a chunk of size 670, which is longer than the specified 400
# Created a chunk of size 511, which is longer than the specified 400
# Created a chunk of size 1213, which is longer than the specified 400
# Created a chunk of size 552, which is longer than the specified 400
# Created a chunk of size 930, which is longer than the specified 400
# Created a chunk of size 1013, which is longer than the specified 400
# Created a chunk of size 998, which is longer than the specified 400
# Created a chunk of size 549, which is longer than the specified 400
# Created a chunk of size 1354, which is longer than the specified 400
# Created a chunk of size 1414, which is longer than the specified 400
# Created a chunk of size 877, which is longer than the specified 400
# Created a chunk of size 1025, which is longer than the specified 400
# Created a chunk of size 1218, which is longer than the specified 400
# Created a chunk of size 1133, which is longer than the specified 400
# Created a chunk of size 494, which is longer than the specified 400
# Created a chunk of size 740, which is longer than the specified 400
# Created a chunk of size 684, which is longer than the specified 400
# Created a chunk of size 516, which is longer than the specified 400
# Created a chunk of size 605, which is longer than the specified 400
# Created a chunk of size 774, which is longer than the specified 400
# Created a chunk of size 779, which is longer than the specified 400
# Created a chunk of size 987, which is longer than the specified 400
# Created a chunk of size 806, which is longer than the specified 400
# Created a chunk of size 956, which is longer than the specified 400
# Created a chunk of size 887, which is longer than the specified 400
# Created a chunk of size 559, which is longer than the specified 400
# Created a chunk of size 592, which is longer than the specified 400
# Created a chunk of size 1197, which is longer than the specified 400
# Created a chunk of size 1893, which is longer than the specified 400
# Created a chunk of size 717, which is longer than the specified 400
# Created a chunk of size 3170, which is longer than the specified 400
# Created a chunk of size 1534, which is longer than the specified 400
# Created a chunk of size 433, which is longer than the specified 400
# Created a chunk of size 409, which is longer than the specified 400
# Created a chunk of size 1590, which is longer than the specified 400
# ...
# Created a chunk of size 626, which is longer than the specified 400
# Created a chunk of size 618, which is longer than the specified 400
# Created a chunk of size 1623, which is longer than the specified 400
# Created a chunk of size 460, which is longer than the specified 400
# Created a chunk of size 995, which is longer than the specified 400
# Created a chunk of size 873, which is longer than the specified 400
# Created a chunk of size 1163, which is longer than the specified 400
# Created a chunk of size 404, which is longer than the specified 400
# Created a chunk of size 576, which is longer than the specified 400
# Created a chunk of size 585, which is longer than the specified 400
# Created a chunk of size 420, which is longer than the specified 400
# Created a chunk of size 969, which is longer than the specified 400
# Created a chunk of size 986, which is longer than the specified 400
# Created a chunk of size 1283, which is longer than the specified 400
# Created a chunk of size 621, which is longer than the specified 400
# Created a chunk of size 438, which is longer than the specified 400
# Created a chunk of size 1475, which is longer than the specified 400
# Created a chunk of size 566, which is longer than the specified 400
# Created a chunk of size 570, which is longer than the specified 400
# Created a chunk of size 1144, which is longer than the specified 400
# Created a chunk of size 487, which is longer than the specified 400
# Created a chunk of size 462, which is longer than the specified 400
# Created a chunk of size 1774, which is longer than the specified 400
# Created a chunk of size 1504, which is longer than the specified 400
# Created a chunk of size 564, which is longer than the specified 400
# Created a chunk of size 445, which is longer than the specified 400
# Created a chunk of size 423, which is longer than the specified 400
# Created a chunk of size 418, which is longer than the specified 400
# Created a chunk of size 2857, which is longer than the specified 400
# Created a chunk of size 600, which is longer than the specified 400
# Created a chunk of size 566, which is longer than the specified 400
# Created a chunk of size 713, which is longer than the specified 400
# Created a chunk of size 420, which is longer than the specified 400
# Created a chunk of size 1090, which is longer than the specified 400
# Created a chunk of size 963, which is longer than the specified 400
# Created a chunk of size 1134, which is longer than the specified 400
# Created a chunk of size 764, which is longer than the specified 400
# Created a chunk of size 1199, which is longer than the specified 400
# Created a chunk of size 1174, which is longer than the specified 400
# Created a chunk of size 961, which is longer than the specified 400
# Created a chunk of size 1216, which is longer than the specified 400
# Created a chunk of size 966, which is longer than the specified 400
# Created a chunk of size 883, which is longer than the specified 400
# Created a chunk of size 1004, which is longer than the specified 400
# Created a chunk of size 406, which is longer than the specified 400
# Created a chunk of size 1472, which is longer than the specified 400
# Created a chunk of size 1473, which is longer than the specified 400
# Created a chunk of size 885, which is longer than the specified 400
# Created a chunk of size 520, which is longer than the specified 400
# Created a chunk of size 501, which is longer than the specified 400
# Created a chunk of size 1217, which is longer than the specified 400
# Created a chunk of size 1862, which is longer than the specified 400
# Created a chunk of size 424, which is longer than the specified 400
# Created a chunk of size 1527, which is longer than the specified 400
# Created a chunk of size 1385, which is longer than the specified 400
# Created a chunk of size 434, which is longer than the specified 400
# Created a chunk of size 1454, which is longer than the specified 400
# Created a chunk of size 1167, which is longer than the specified 400
# Created a chunk of size 929, which is longer than the specified 400
# Created a chunk of size 883, which is longer than the specified 400
# Created a chunk of size 501, which is longer than the specified 400
# Created a chunk of size 815, which is longer than the specified 400
# Created a chunk of size 947, which is longer than the specified 400
# Created a chunk of size 1005, which is longer than the specified 400
# Created a chunk of size 1362, which is longer than the specified 400
# Created a chunk of size 925, which is longer than the specified 400
# Created a chunk of size 1341, which is longer than the specified 400
# Created a chunk of size 836, which is longer than the specified 400
# Created a chunk of size 530, which is longer than the specified 400
# Created a chunk of size 1050, which is longer than the specified 400
# Created a chunk of size 570, which is longer than the specified 400
# Created a chunk of size 1340, which is longer than the specified 400
# Created a chunk of size 1603, which is longer than the specified 400
# Created a chunk of size 1057, which is longer than the specified 400
# Created a chunk of size 1267, which is longer than the specified 400
# Created a chunk of size 406, which is longer than the specified 400
# Created a chunk of size 771, which is longer than the specified 400
# Created a chunk of size 1028, which is longer than the specified 400
# Created a chunk of size 527, which is longer than the specified 400
# Created a chunk of size 728, which is longer than the specified 400
# Created a chunk of size 677, which is longer than the specified 400
# Created a chunk of size 825, which is longer than the specified 400
# Created a chunk of size 831, which is longer than the specified 400
# Created a chunk of size 574, which is longer than the specified 400
# Created a chunk of size 1036, which is longer than the specified 400
# Created a chunk of size 742, which is longer than the specified 400
# Created a chunk of size 575, which is longer than the specified 400
# Created a chunk of size 899, which is longer than the specified 400
# Created a chunk of size 1432, which is longer than the specified 400
# Created a chunk of size 875, which is longer than the specified 400
# Created a chunk of size 2869, which is longer than the specified 400
# Created a chunk of size 2347, which is longer than the specified 400
# Created a chunk of size 530, which is longer than the specified 400
# Created a chunk of size 2453, which is longer than the specified 400
# Created a chunk of size 903, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 402, which is longer than the specified 400
# Created a chunk of size 1054, which is longer than the specified 400
# Created a chunk of size 1510, which is longer than the specified 400
# Created a chunk of size 923, which is longer than the specified 400
# Created a chunk of size 1115, which is longer than the specified 400
# Created a chunk of size 1111, which is longer than the specified 400
# Created a chunk of size 772, which is longer than the specified 400
# Created a chunk of size 740, which is longer than the specified 400
# Created a chunk of size 922, which is longer than the specified 400
# Created a chunk of size 723, which is longer than the specified 400
# Created a chunk of size 926, which is longer than the specified 400
# Created a chunk of size 632, which is longer than the specified 400
# Created a chunk of size 402, which is longer than the specified 400
# Created a chunk of size 1514, which is longer than the specified 400
# Created a chunk of size 1302, which is longer than the specified 400
# Created a chunk of size 603, which is longer than the specified 400
# Created a chunk of size 799, which is longer than the specified 400
# Created a chunk of size 431, which is longer than the specified 400
# Created a chunk of size 431, which is longer than the specified 400
# Created a chunk of size 839, which is longer than the specified 400
# Created a chunk of size 431, which is longer than the specified 400
# Created a chunk of size 1136, which is longer than the specified 400
# Created a chunk of size 1350, which is longer than the specified 400
# Created a chunk of size 682, which is longer than the specified 400
# Created a chunk of size 581, which is longer than the specified 400
# Created a chunk of size 956, which is longer than the specified 400
# Created a chunk of size 685, which is longer than the specified 400
# Created a chunk of size 729, which is longer than the specified 400
# Created a chunk of size 658, which is longer than the specified 400
# Created a chunk of size 1086, which is longer than the specified 400
# Created a chunk of size 796, which is longer than the specified 400
# Created a chunk of size 800, which is longer than the specified 400
# Created a chunk of size 1000, which is longer than the specified 400
# Created a chunk of size 962, which is longer than the specified 400
# Created a chunk of size 661, which is longer than the specified 400
# Created a chunk of size 758, which is longer than the specified 400
# Created a chunk of size 511, which is longer than the specified 400
# Created a chunk of size 562, which is longer than the specified 400
# Created a chunk of size 504, which is longer than the specified 400
# Created a chunk of size 670, which is longer than the specified 400
# Created a chunk of size 677, which is longer than the specified 400
# Created a chunk of size 858, which is longer than the specified 400
# Created a chunk of size 1110, which is longer than the specified 400
# Created a chunk of size 542, which is longer than the specified 400
# Created a chunk of size 453, which is longer than the specified 400
# Created a chunk of size 983, which is longer than the specified 400
# Created a chunk of size 1340, which is longer than the specified 400
# Created a chunk of size 761, which is longer than the specified 400
# Created a chunk of size 419, which is longer than the specified 400
# Created a chunk of size 1300, which is longer than the specified 400
# Created a chunk of size 722, which is longer than the specified 400
# Created a chunk of size 1320, which is longer than the specified 400
# Created a chunk of size 1524, which is longer than the specified 400
# Created a chunk of size 1033, which is longer than the specified 400
# Created a chunk of size 707, which is longer than the specified 400
# Created a chunk of size 1257, which is longer than the specified 400
# Created a chunk of size 712, which is longer than the specified 400
# Created a chunk of size 1127, which is longer than the specified 400
# Created a chunk of size 1295, which is longer than the specified 400
# Created a chunk of size 1043, which is longer than the specified 400
# Created a chunk of size 502, which is longer than the specified 400
# Created a chunk of size 1152, which is longer than the specified 400
# Created a chunk of size 935, which is longer than the specified 400
# Created a chunk of size 663, which is longer than the specified 400
# Created a chunk of size 882, which is longer than the specified 400
# Created a chunk of size 890, which is longer than the specified 400
# Created a chunk of size 572, which is longer than the specified 400
# Created a chunk of size 895, which is longer than the specified 400
# Created a chunk of size 530, which is longer than the specified 400
# Created a chunk of size 556, which is longer than the specified 400
# Created a chunk of size 911, which is longer than the specified 400
# Created a chunk of size 965, which is longer than the specified 400
# Created a chunk of size 868, which is longer than the specified 400
# Created a chunk of size 531, which is longer than the specified 400
# Created a chunk of size 408, which is longer than the specified 400
# Created a chunk of size 633, which is longer than the specified 400
# Created a chunk of size 485, which is longer than the specified 400
# Created a chunk of size 512, which is longer than the specified 400
# Created a chunk of size 475, which is longer than the specified 400
# Created a chunk of size 651, which is longer than the specified 400
# Created a chunk of size 463, which is longer than the specified 400
# Created a chunk of size 907, which is longer than the specified 400
# Created a chunk of size 606, which is longer than the specified 400
# Created a chunk of size 567, which is longer than the specified 400
# Created a chunk of size 527, which is longer than the specified 400
# Created a chunk of size 1157, which is longer than the specified 400
# Created a chunk of size 1352, which is longer than the specified 400
# Created a chunk of size 1403, which is longer than the specified 400
# Created a chunk of size 977, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 415, which is longer than the specified 400
# Created a chunk of size 582, which is longer than the specified 400
# Created a chunk of size 639, which is longer than the specified 400
# Created a chunk of size 1898, which is longer than the specified 400
# Created a chunk of size 2149, which is longer than the specified 400
# Created a chunk of size 1417, which is longer than the specified 400
# Created a chunk of size 588, which is longer than the specified 400
# Created a chunk of size 1419, which is longer than the specified 400
# Created a chunk of size 842, which is longer than the specified 400
# Created a chunk of size 488, which is longer than the specified 400
# Created a chunk of size 507, which is longer than the specified 400
# Created a chunk of size 1282, which is longer than the specified 400
# Created a chunk of size 679, which is longer than the specified 400
# Created a chunk of size 801, which is longer than the specified 400
# Created a chunk of size 1043, which is longer than the specified 400
# Created a chunk of size 418, which is longer than the specified 400
# Created a chunk of size 868, which is longer than the specified 400
# Created a chunk of size 605, which is longer than the specified 400
# Created a chunk of size 406, which is longer than the specified 400
# Created a chunk of size 1182, which is longer than the specified 400
# Created a chunk of size 654, which is longer than the specified 400
# Created a chunk of size 1002, which is longer than the specified 400
# Created a chunk of size 798, which is longer than the specified 400
# Created a chunk of size 3938, which is longer than the specified 400
# Created a chunk of size 925, which is longer than the specified 400
# Created a chunk of size 697, which is longer than the specified 400
# Created a chunk of size 855, which is longer than the specified 400
# Created a chunk of size 930, which is longer than the specified 400
# Created a chunk of size 550, which is longer than the specified 400
# Created a chunk of size 1021, which is longer than the specified 400
# Created a chunk of size 442, which is longer than the specified 400
# Created a chunk of size 1273, which is longer than the specified 400
# Created a chunk of size 1531, which is longer than the specified 400
# Created a chunk of size 444, which is longer than the specified 400
# Created a chunk of size 614, which is longer than the specified 400
# Created a chunk of size 1304, which is longer than the specified 400
# Created a chunk of size 521, which is longer than the specified 400
# Created a chunk of size 999, which is longer than the specified 400
# Created a chunk of size 769, which is longer than the specified 400
# Created a chunk of size 563, which is longer than the specified 400
# Created a chunk of size 651, which is longer than the specified 400
# Created a chunk of size 1050, which is longer than the specified 400
# Created a chunk of size 1274, which is longer than the specified 400
# Created a chunk of size 952, which is longer than the specified 400
# Created a chunk of size 453, which is longer than the specified 400
# Created a chunk of size 682, which is longer than the specified 400
# Created a chunk of size 586, which is longer than the specified 400
# Created a chunk of size 765, which is longer than the specified 400

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='"9780002005883 A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike."')

# %%
db_books = Chroma.from_documents(
    documents,
    embedding = OpenAIEmbeddings())

# %%
query = "A book to teach children about nature"
docs = db_books.similarity_search(query, k=10)
docs
# Out:
# [Document(id='02a32cac-228c-445a-986f-df8c5c6feaec', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience."'),
#  Document(id='3f68b1d3-2d5b-4b2a-bcb7-50654e2f2bb4', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808380 Introduce your babies to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing the baby to some basic -- and sometimes playful -- information about the subjects."'),
#  Document(id='5543416c-4ffc-4cf9-8066-4055124287a5', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808397 Introduce your baby to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to exopse little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information about the subjects."'),
#  Document(id='3b485b70-ddae-4f99-8f4b-ea2377db1574', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808717 A very special puddle sets Violet the mouse off on her latest nature discovery. It is through this puddle that Violet observes the effect rain has on the world around her. A Mylar puddle on the last page offers children a chance to see their reflection in a puddle, just like Violet!"'),
#  Document(id='689c860c-c637-4998-a4ee-d841096ca731', metadata={'source': 'tagged_description.txt'}, page_content='"9780786812912 In her first illustrated book for children, the Pulitzer Prize–winning author Toni Morrison introduces three feisty children who show grown-ups what it really means to be a kid."'),
#  Document(id='f8483be2-e899-437a-ab19-57cc2b990ff4', metadata={'source': 'tagged_description.txt'}, page_content='"9780067575208 First published more than three decades ago, this reissue of Rachel Carson\'s award-winning classic brings her unique vision to a new generation of readers. Stunning new photographs by Nick Kelsh beautifully complement Carson\'s intimate account of adventures with her young nephew, Roger, as they enjoy walks along the rocky coast of Maine and through dense forests and open fields, observing wildlife, strange plants, moonlight and storm clouds, and listening to the ""living music"" of insects in the underbrush. ""If a child is to keep alive his inborn sense of wonder."" Writes Carson, ""he needs the companionship of at least one adult who can share it, rediscovering with him the joy, excitement and mystery of the world we live in."" The Sense of Wonder is a refreshing antidote to indifference and a guide to capturing the simple power of discovery that Carson views as essential to life. In her insightful new introduction, Linda Lear remembers Rachel Carson\'s groundbreaking achievements in the context of the legendary environmentalist\'s personal commitment to introducing young and old to the miracles of nature. Kelsh\'s lush photographs inspire sensual, tactile reactions: masses of leaves floating in a puddle are just waiting to be scooped up and examined more closely. An image of a narrow path through the trees evokes the earthy scent of the woods after a summer rain. Close-ups of mosses and miniature lichen fantasy-lands will spark innocent\'as well as more jaded\'imaginations. Like a curious child studying things underfoot and within reach, Kelsh\'s camera is drawn to patterns in nature that too often elude hurried adults\'a stand of beech trees in the springtime, patches of melting snow and the ripples from a pebble tossed into a slow-moving stream. The Sense of Wonder is a timeless volume that will be passed on from children to grandchildren, as treasured as the memory of an early-morning walk when the song of a whippoorwill was heard as if for the first time."'),
#  Document(id='369b2e69-d420-4dba-8134-07a9bd743576', metadata={'source': 'tagged_description.txt'}, page_content="9780241003008 Eric Carle's children's classic is the story of a very small and very hungry caterpillar who manages to nibble his way through the pages of this enchanting book."),
#  Document(id='4c4bbfc3-1deb-436a-bb64-c022f1cf5dd0', metadata={'source': 'tagged_description.txt'}, page_content='"9780763620875 When Judy Moody gets serious about protecting the environment, her little brother Stink thinks she is overdoing it, but she manages to inspire her third grade class to undertake an award-winning, environment-saving project. Reprint."'),
#  Document(id='8e367d88-ca2a-44f6-8b24-06dce02ea076', metadata={'source': 'tagged_description.txt'}, page_content='"9780764122781 Titles in this series present basic information on reptiles plus specific instructions for their care. Each book opens with a description of the animal as it exists in its natural habitat, then continues with information on its life cycle and distribution in nature. Readers then get advice on selecting a good specimen, determining sex, and providing proper housing, feeding, and health care. Books are heavily illustrated with instructive color photos."'),
#  Document(id='6e2f0a20-fe4e-46cf-9efe-07e4915bee9f', metadata={'source': 'tagged_description.txt'}, page_content='"9780689861130 Children will love joining in and imitating the animal noises and sounds in this big, bold board book format, illustrated with Sandra Boynton\'s seriously silly signature animals."\n"9780689862465 Whistler and Lila, two of the mice children who live in a lighthouse, meet a young octopus when they visit the beach during low tide."')]

# %%
isbn_str = docs[0].page_content.split()[0].strip().replace('"', '')
books[books["isbn13"] == int(isbn_str)]
# Out:
#              isbn13                            authors        categories  \
# 3657  9780786808069  Marilyn Singer;Julie Aigner-Clark  Juvenile Fiction
#
#                                               thumbnail  \
# 3657  http://books.google.com/books/content?id=X9a4P...
#
#                                             description  published_year  \
# 3657  Children will discover the exciting world of t...          2001.0
#
#       average_rating  num_pages  ratings_count  \
# 3657            3.89       16.0          180.0
#
#                          title_&_subtitle  \
# 3657  Baby Einstein: Neighborhood Animals
#
#                                      tagged_description
# 3657  9780786808069 Children will discover the excit...

# %%
def retrieve_semantic_recommendations(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    recs = db_books.similarity_search(query, k=50)
    books_list = []

    for i in range(0, len(recs)):
        books_list += [int(recs[i].page_content.strip('"').split()[0])]

    return books[books["isbn13"].isin(books_list)].head(top_k)

# %%
retrieve_semantic_recommendations("A book to teach children about nature")
# Out:
#             isbn13                                          authors  \
# 30   9780007105045                        John Ronald Reuel Tolkien
# 58   9780007151240                                     Tony Parsons
# 141  9780060546571                                  Gregory Maguire
# 321  9780060959036                               Barbara Kingsolver
# 396  9780062700254                                Richard P. Martin
# 425  9780064434980                             Laura Ingalls Wilder
# 438  9780067575208                                    Rachel Carson
# 682  9780140448009  Gustave Flaubert;Roger Whitehouse;Geoffrey Wall
# 701  9780140621624                                        E. Nesbit
# 800  9780142302279                                       Roald Dahl
#
#                categories                                          thumbnail  \
# 30   Literary Collections  http://books.google.com/books/content?id=aPb_A...
# 58             Parenthood  http://books.google.com/books/content?id=dJEIx...
# 141      Juvenile Fiction  http://books.google.com/books/content?id=t2pWl...
# 321               Fiction  http://books.google.com/books/content?id=06IwG...
# 396             Reference  http://books.google.com/books/content?id=eev4u...
# 425      Juvenile Fiction  http://books.google.com/books/content?id=V7YDW...
# 438                Nature  http://books.google.com/books/content?id=Zee5S...
# 682               Fiction  http://books.google.com/books/content?id=XFzga...
# 701               Fiction  http://books.google.com/books/content?id=fFesd...
# 800   Juvenile Nonfiction                                           No Image
#
#                                            description  published_year  \
# 30   "The two works 'On fairy-stories' and 'Leaf by...          2001.0
# 58   It should be the most natural thing in the wor...          2005.0
# 141  The students of Miss Earth's class in rural Ve...          2005.0
# 321  Barbara Kingsolver's fifth novel is a hymn to ...          2001.0
# 396  A beautiful gift edition of Thomas Bulfinch's ...          1991.0
# 425  Even the youngest child can enjoy a special ad...          1999.0
# 438  First published more than three decades ago, t...          1998.0
# 682  Features short fiction by the French naturalis...          2005.0
# 701  When their father is sent away to prison, thre...          1995.0
# 800  Poems tell the stories of a smart pig who outw...          2002.0
#
#      average_rating  num_pages  ratings_count  \
# 30             4.09      176.0         2245.0
# 58             3.51      400.0         2095.0
# 141            3.74      240.0           76.0
# 321            4.00      444.0        85440.0
# 396            4.10      768.0           64.0
# 425            4.17       32.0          302.0
# 438            4.39      112.0         1160.0
# 682            3.71      110.0         3050.0
# 701            4.00      212.0          178.0
# 800            4.02       32.0         3953.0
#
#                                       title_&_subtitle  \
# 30   Tree and Leaf: The Homecoming of Beorhtnoth : ...
# 58                                      The Family Way
# 141                                  Three Rotten Eggs
# 321                           Prodigal Summer: A Novel
# 396  Bulfinch's Mythology: The Age of the Fable, Th...
# 425                               The Deer in the Wood
# 438                                The Sense of Wonder
# 682                                        Three Tales
# 701                               The Railway Children
# 800                                       Dirty Beasts
#
#                                     tagged_description
# 30   9780007105045 "The two works 'On fairy-stories...
# 58   9780007151240 It should be the most natural th...
# 141  9780060546571 The students of Miss Earth's cla...
# 321  9780060959036 Barbara Kingsolver's fifth novel...
# 396  9780062700254 A beautiful gift edition of Thom...
# 425  9780064434980 Even the youngest child can enjo...
# 438  9780067575208 First published more than three ...
# 682  9780140448009 Features short fiction by the Fr...
# 701  9780140621624 When their father is sent away t...
# 800  9780142302279 Poems tell the stories of a smar...
